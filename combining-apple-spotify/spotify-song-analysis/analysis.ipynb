# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the data
spotifyHeartRate = pd.read_csv('GenreSpotifyHeartRate.csv')
spotifyStepsCount = pd.read_csv('GenreSpotifyStepsCount.csv')

# %%
#columns in the data
print(spotifyHeartRate.columns)
# Out:
# Index(['startDate', 'ms_played', 'track_name_x', 'artist_name', 'album_name_x',
#        'track_id', 'type', 'sourceName', 'value', 'unit', 'endDate',
#        'Unnamed: 0', 'artists', 'album_name_y', 'track_name_y', 'popularity',
#        'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'track_genre'],
#       dtype='object')

# %%
#drop type column
spotifyHeartRate = spotifyHeartRate.drop(columns=['type'])

# %%
spotifyHeartRate = spotifyHeartRate.drop(columns=['sourceName'])

# %%
spotifyHeartRate.head(20)
# Out:
#               startDate  ms_played                  track_name_x  \
# 0   2023-11-09 18:30:00          0            Kya Mujhe Pyar Hai
# 1   2023-11-09 18:30:00          0            Kya Mujhe Pyar Hai
# 2   2023-11-09 18:40:00     115970                     Tum Hi Ho
# 3   2023-11-09 18:40:00     115970                     Tum Hi Ho
# 4   2023-11-09 18:50:00     390222  Sunn Raha Hai (Male Version)
# 5   2023-11-09 18:50:00     390222  Sunn Raha Hai (Male Version)
# 6   2023-11-09 19:00:00     143149                    Bhula Dena
# 7   2023-11-09 19:00:00     143149                    Bhula Dena
# 8   2023-11-09 19:10:00       1190             Tum Hi Ho (Remix)
# 9   2023-11-09 19:20:00     159220         Woh Lamhe Woh Baatein
# 10  2023-11-09 19:20:00     159220         Woh Lamhe Woh Baatein
# 11  2023-11-09 19:30:00      55003              Zara Zara - Lofi
# 12  2023-11-09 19:30:00      55003              Zara Zara - Lofi
# ...
