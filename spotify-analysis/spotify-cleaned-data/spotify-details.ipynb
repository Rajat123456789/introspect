# %%
import pandas as pd
import numpy as numpy
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('spotify-history-cleaned.csv')

# %%
df.head()
# Out:
#                     end_time  ms_played              track_name  \
# 0  2023-11-09 18:38:14+00:00      79270  Chaleya (From "Jawan")
# 1  2023-11-09 18:38:19+00:00       1760                 Zara Sa
# 2  2023-11-09 18:38:20+00:00          0      Kya Mujhe Pyar Hai
# 3  2023-11-09 18:42:23+00:00     241668                 Ajab Si
# 4  2023-11-09 18:42:26+00:00       1481                   Sajde
#
#            artist_name                                   album_name  \
# 0  Anirudh Ravichander                       Chaleya (From "Jawan")
# 1               Pritam  Jannat (Original Motion Picture Soundtrack)
# 2                   KK                                    Woh Lamhe
# 3                   KK                                 Om Shanti Om
# 4               Pritam                                Khatta Meetha
#
#                                     url           start_time
# 0  spotify:track:4nc6XiUze2Yh7wFueGOPv7  2023-11-09 18:36:54
# ...

# %%
#only keep track id from the url

df['url'] = df['url'].str.split(':').str[-1]

# %%
df.head()
# Out:
#                     end_time  ms_played              track_name  \
# 0  2023-11-09 18:38:14+00:00      79270  Chaleya (From "Jawan")
# 1  2023-11-09 18:38:19+00:00       1760                 Zara Sa
# 2  2023-11-09 18:38:20+00:00          0      Kya Mujhe Pyar Hai
# 3  2023-11-09 18:42:23+00:00     241668                 Ajab Si
# 4  2023-11-09 18:42:26+00:00       1481                   Sajde
#
#            artist_name                                   album_name  \
# 0  Anirudh Ravichander                       Chaleya (From "Jawan")
# 1               Pritam  Jannat (Original Motion Picture Soundtrack)
# 2                   KK                                    Woh Lamhe
# 3                   KK                                 Om Shanti Om
# 4               Pritam                                Khatta Meetha
#
#                       url           start_time
# 0  4nc6XiUze2Yh7wFueGOPv7  2023-11-09 18:36:54
# 1  18YHbIhrleUkKKj2DvEp79  2023-11-09 18:38:15
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth

# Spotify API credentials (replace with your own credentials)
CLIENT_ID = 'da07024f200a4ea99701afb3cf8e4054'
CLIENT_SECRET = '50d840c956114871af57aa7cd9341c2f'
REDIRECT_URI = 'http://localhost:8888/callback'

# Initialize the Spotify API client
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=CLIENT_ID,
                                               client_secret=CLIENT_SECRET,
                                               redirect_uri=REDIRECT_URI,
                                               scope=["user-library-read"]))

# Song URL (replace with the URL of the song you want to analyze)
song_url = 'spotify:track:4nc6XiUze2Yh7wFueGOPv7'  # Example song URL

# Extract track ID from the URL
track_id = song_url.split(":")[2]

# Fetch the audio features for the track
features = sp.audio_features(track_id)

if features:
    # Extract and display the required features
    feature = features[0]
    tempo = feature.get('tempo', 'N/A')
    danceability = feature.get('danceability', 'N/A')
    valence = feature.get('valence', 'N/A')
    
    print(f"Track ID: {track_id}")
    print(f"Tempo: {tempo}")
    print(f"Danceability: {danceability}")
    print(f"Valence: {valence}")
else:
    print("Failed to retrieve audio features.")
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/audio-features/?ids=4nc6XiUze2Yh7wFueGOPv7 with Params: {} returned 403 due to None
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/anaconda3/envs/captionKraftNov25/lib/python3.9/site-packages/spotipy/client.py:275, in Spotify._internal_call(self, method, url, payload, params)
#     270 response = self._session.request(
#     271     method, url, headers=headers, proxies=self.proxies,
#     272     timeout=self.requests_timeout, **args
#     273 )
# --> 275 response.raise_for_status()
#     276 results = response.json()
#
# File ~/anaconda3/envs/captionKraftNov25/lib/python3.9/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# ...
